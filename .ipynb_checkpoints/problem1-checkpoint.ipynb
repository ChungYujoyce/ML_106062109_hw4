# %%
import random
from math import exp
import matplotlib.pyplot as plt
# process data label as 0, 1, 2 for training
def loadDataset(dataset): 
    newdata = []
    for x in range(len(dataset)-1):
        for i in range(0,len(dataset[x]),4):
            if dataset[x][i] == "I": # encounter labels, change it
                if dataset[x][-3:-1] == "sa": # Iris-setosa
                    newdata.append(0)
                elif dataset[x][-2:-1] == "r": # Iris-versicolor
                    newdata.append(1)
                elif dataset[x][-3:-1] == "ca": # Iris-virginica
                    newdata.append(2) 
                break
            else:
                attribute = float(dataset[x][i:i+3])
                newdata.append(attribute)
        trainingSet.append(newdata)       
        newdata = [] # clear the package
    return trainingSet

# find the range of data to do normalize
def dataset_minmax(dataset): # zip a(1,2,3) , b(4,5,6) to [(1,4), (2,5), (3,6)] 
    minmax = list()
    stats = [[min(column), max(column)] for column in zip(*dataset)] # unzip the file
    return stats

# rescale data to range 0~1
def normalize_data(dataset, minmax):
    for row in dataset:
        for i in range(len(row)-1):
            row[i] = (row[i] - minmax[i][0]) / (minmax[i][1] - minmax[i][0])

# calculate neuron activation for an input
def activate(weights, inputs):
    activation = weights[-1]
    for i in range(len(weights)-1):
        activation += weights[i] * inputs[i]
    return activation

# transfer neuron activation 
def transfer(activation):
    return 1.0 / (1.0 + exp(-activation))

# calculate the derivative of an neuron output
def transfer_derivative(output):
    return output * (1.0 - output)

#forward propagate input to a network output
def forward_propagate(network, row):
    inputs = row
    for layer in network:
        new_inputs = []
        for neuron in layer:
            activation = activate(neuron['weights'], inputs)
            neuron['output'] = transfer(activation)
            new_inputs.append(neuron['output'])
        inputs = new_inputs # keep updating the neurons
    return inputs

# backpropagate error and sotre in neurons
def backward_propagate_error(network, expected): 
    for i in reversed(range(len(network))):
        layer = network[i]
        errors = list()
        if i != len(network)-1:
            for j in range(len(layer)): # hidden
                error = 0.0
                for neuron in network[i+1]:
                    error += (neuron['weights'][j] * neuron['delta'])
                errors.append(error) 
        else:
            for j in range(len(layer)): # output
                neuron = layer[j]
                errors.append(expected[j] - neuron['output'])
        for j in range(len(layer)):
            neuron = layer[j]
            neuron['delta'] = errors[j] * transfer_derivative(neuron['output'])

# update network weights with error
def update_weights(network, row, learning_rate):
    for i in range(len(network)):
        inputs = row[:-1]
        if i != 0:
            inputs = [neuron['output'] for neuron in network[i-1]]
        for neuron in network[i]:
            for j in range(len(inputs)):
                neuron['weights'][j] += learning_rate * neuron['delta'] * inputs[j]
            neuron['weights'][-1] += learning_rate * neuron['delta']

def train_network(network, train, learning_rate, n_epoch, n_outputs):
    SE = []
    EPOCH = [i for i in range(n_epoch)]
    AC = []
    for epoch in range(n_epoch):
        sum_error = 0
        for row in train:
            outputs = forward_propagate(network, row)
            expected = [0 for i in range(n_outputs)]
            expected[row[-1]] = 1 # one hot encoding !!!
            sum_error += sum([(expected[i]-outputs[i])**2 for i in range(len(expected))])
            backward_propagate_error(network, expected)
            update_weights(network, row, learning_rate)
        print('>epoch=%d, lrate=%.3f, error=%.3f' % (epoch, learning_rate, sum_error))
        SE.append(sum_error)
        predicted = [predict(network, row) for row in train]
        actual = [row[-1] for row in train]
        accuracy = accuracy_metric(actual, predicted)
        AC.append(accuracy)
    plt.plot(EPOCH, SE, 'r')
    plt.ylabel("Sum of error")
    plt.xlabel("Number of epochs")
    plt.show()
   
    plt.plot(EPOCH, AC, 'b')
    plt.ylabel("Accuracy")
    plt.xlabel("Number of epochs")
    plt.show()
def accuracy_metric(actual, predicted):
    correct = 0
    for i in range(len(actual)):
        if actual[i] == predicted[i]:
            correct += 1
    return correct / float(len(actual)) * 100.0 

def init_network(n_inputs, n_hidden, n_outputs): 
# create n_hidden neurons and each neuron in the hidden layer has n_inputs + 1 weights
    network = list()
    hidden_layer1 = [{'weights': [(random.random()-0.5)/5.0 for i in range(n_inputs + 1)]} for i in range(n_hidden)]
    network.append(hidden_layer1) # 4 neurons with 4 input weights plus the bias
    hidden_layer2 = [{'weights': [(random.random()-0.5)/5.0 for i in range(n_inputs + 1)]} for i in range(n_hidden)]
    network.append(hidden_layer2)
    output_layer = [{'weights': [(random.random()-0.5)/5.0 for i in range(n_hidden + 1)]} for i in range(n_outputs)]
    #print("out",hidden_layer)
    network.append(output_layer) # 3 neurons with 4 input weights plus the bias
    #for layer in network:
     #   print(layer)
    return network

# make a prediction with a network
# It returns the index in the network output that has the largest probability. 
# Assuming that class values have been converted to integers starting at 0. [0,1,2]
def predict(network, row):
    outputs = forward_propagate(network, row)
    return outputs.index(max(outputs))

# backpropagation with stochastic gradient descent
def back_propagate(train, learning_rate, n_epoch, n_hidden):
    n_inputs = len(train[0]) - 1
    n_outputs = len(set([row[-1] for row in train]))
    network = init_network(n_inputs, n_hidden, n_outputs)
    train_network(network, train, learning_rate, n_epoch, n_outputs)

# %%
trainingSet=[]
testSet=[]

f = open('iris.data.txt', "r")
lines = f.readlines()
dataset = list(lines)
trainingSet = loadDataset(dataset)

# %%
# normalize inputs

minmax = dataset_minmax(trainingSet)
normalize_data(trainingSet, minmax)

learning_rate = 0.1
n_epoch = 500
n_hidden = 4 # neuron per layer

back_propagate(trainingSet, learning_rate, n_epoch, n_hidden)
# Out:
# >epoch=0, lrate=0.100, error=92.328
# >epoch=1, lrate=0.100, error=95.210
# >epoch=2, lrate=0.100, error=96.463
# >epoch=3, lrate=0.100, error=96.759
# >epoch=4, lrate=0.100, error=96.841
# >epoch=5, lrate=0.100, error=96.874
# >epoch=6, lrate=0.100, error=96.897
# >epoch=7, lrate=0.100, error=96.917
# >epoch=8, lrate=0.100, error=96.937
# >epoch=9, lrate=0.100, error=96.956
# >epoch=10, lrate=0.100, error=96.975
# >epoch=11, lrate=0.100, error=96.994
# >epoch=12, lrate=0.100, error=97.013
# >epoch=13, lrate=0.100, error=97.032
# >epoch=14, lrate=0.100, error=97.051
# >epoch=15, lrate=0.100, error=97.069
# >epoch=16, lrate=0.100, error=97.087
# >epoch=17, lrate=0.100, error=97.106
# >epoch=18, lrate=0.100, error=97.124
# >epoch=19, lrate=0.100, error=97.142
# >epoch=20, lrate=0.100, error=97.159
# >epoch=21, lrate=0.100, error=97.177
# >epoch=22, lrate=0.100, error=97.195
# >epoch=23, lrate=0.100, error=97.212
# >epoch=24, lrate=0.100, error=97.229
# >epoch=25, lrate=0.100, error=97.246
# >epoch=26, lrate=0.100, error=97.263
# >epoch=27, lrate=0.100, error=97.280
# >epoch=28, lrate=0.100, error=97.297
# >epoch=29, lrate=0.100, error=97.313
# >epoch=30, lrate=0.100, error=97.330
# >epoch=31, lrate=0.100, error=97.346
# >epoch=32, lrate=0.100, error=97.363
# >epoch=33, lrate=0.100, error=97.379
# >epoch=34, lrate=0.100, error=97.395
# >epoch=35, lrate=0.100, error=97.410
# >epoch=36, lrate=0.100, error=97.426
# >epoch=37, lrate=0.100, error=97.442
# >epoch=38, lrate=0.100, error=97.457
# >epoch=39, lrate=0.100, error=97.472
# >epoch=40, lrate=0.100, error=97.488
# >epoch=41, lrate=0.100, error=97.503
# >epoch=42, lrate=0.100, error=97.518
# >epoch=43, lrate=0.100, error=97.532
# >epoch=44, lrate=0.100, error=97.547
# >epoch=45, lrate=0.100, error=97.562
# >epoch=46, lrate=0.100, error=97.576
# >epoch=47, lrate=0.100, error=97.591
# >epoch=48, lrate=0.100, error=97.605
# >epoch=49, lrate=0.100, error=97.619
# >epoch=50, lrate=0.100, error=97.633
# >epoch=51, lrate=0.100, error=97.647
# >epoch=52, lrate=0.100, error=97.660
# >epoch=53, lrate=0.100, error=97.674
# >epoch=54, lrate=0.100, error=97.688
# >epoch=55, lrate=0.100, error=97.701
# >epoch=56, lrate=0.100, error=97.714
# >epoch=57, lrate=0.100, error=97.727
# >epoch=58, lrate=0.100, error=97.740
# >epoch=59, lrate=0.100, error=97.753
# >epoch=60, lrate=0.100, error=97.766
# >epoch=61, lrate=0.100, error=97.779
# >epoch=62, lrate=0.100, error=97.792
# >epoch=63, lrate=0.100, error=97.804
# >epoch=64, lrate=0.100, error=97.817
# >epoch=65, lrate=0.100, error=97.829
# >epoch=66, lrate=0.100, error=97.841
# >epoch=67, lrate=0.100, error=97.853
# >epoch=68, lrate=0.100, error=97.865
# >epoch=69, lrate=0.100, error=97.877
# >epoch=70, lrate=0.100, error=97.889
# >epoch=71, lrate=0.100, error=97.900
# >epoch=72, lrate=0.100, error=97.912
# >epoch=73, lrate=0.100, error=97.923
# >epoch=74, lrate=0.100, error=97.935
# >epoch=75, lrate=0.100, error=97.946
# >epoch=76, lrate=0.100, error=97.957
# >epoch=77, lrate=0.100, error=97.968
# >epoch=78, lrate=0.100, error=97.979
# >epoch=79, lrate=0.100, error=97.990
# >epoch=80, lrate=0.100, error=98.001
# >epoch=81, lrate=0.100, error=98.011
# >epoch=82, lrate=0.100, error=98.022
# >epoch=83, lrate=0.100, error=98.033
# >epoch=84, lrate=0.100, error=98.043
# >epoch=85, lrate=0.100, error=98.053
# >epoch=86, lrate=0.100, error=98.063
# >epoch=87, lrate=0.100, error=98.074
# >epoch=88, lrate=0.100, error=98.084
# >epoch=89, lrate=0.100, error=98.094
# >epoch=90, lrate=0.100, error=98.103
# >epoch=91, lrate=0.100, error=98.113
# >epoch=92, lrate=0.100, error=98.123
# >epoch=93, lrate=0.100, error=98.133
# >epoch=94, lrate=0.100, error=98.142
# >epoch=95, lrate=0.100, error=98.151
# >epoch=96, lrate=0.100, error=98.161
# >epoch=97, lrate=0.100, error=98.170
# >epoch=98, lrate=0.100, error=98.179
# >epoch=99, lrate=0.100, error=98.188
# >epoch=100, lrate=0.100, error=98.197
# >epoch=101, lrate=0.100, error=98.206
# >epoch=102, lrate=0.100, error=98.215
# >epoch=103, lrate=0.100, error=98.224
# >epoch=104, lrate=0.100, error=98.233
# >epoch=105, lrate=0.100, error=98.241
# >epoch=106, lrate=0.100, error=98.250
# >epoch=107, lrate=0.100, error=98.258
# >epoch=108, lrate=0.100, error=98.267
# >epoch=109, lrate=0.100, error=98.275
# >epoch=110, lrate=0.100, error=98.283
# >epoch=111, lrate=0.100, error=98.291
# >epoch=112, lrate=0.100, error=98.300
# >epoch=113, lrate=0.100, error=98.308
# >epoch=114, lrate=0.100, error=98.316
# >epoch=115, lrate=0.100, error=98.323
# >epoch=116, lrate=0.100, error=98.331
# >epoch=117, lrate=0.100, error=98.339
# >epoch=118, lrate=0.100, error=98.347
# >epoch=119, lrate=0.100, error=98.354
# >epoch=120, lrate=0.100, error=98.362
# >epoch=121, lrate=0.100, error=98.369
# >epoch=122, lrate=0.100, error=98.377
# >epoch=123, lrate=0.100, error=98.384
# >epoch=124, lrate=0.100, error=98.392
# >epoch=125, lrate=0.100, error=98.399
# >epoch=126, lrate=0.100, error=98.406
# >epoch=127, lrate=0.100, error=98.413
# >epoch=128, lrate=0.100, error=98.420
# >epoch=129, lrate=0.100, error=98.427
# >epoch=130, lrate=0.100, error=98.434
# >epoch=131, lrate=0.100, error=98.441
# >epoch=132, lrate=0.100, error=98.448
# >epoch=133, lrate=0.100, error=98.454
# >epoch=134, lrate=0.100, error=98.461
# >epoch=135, lrate=0.100, error=98.468
# >epoch=136, lrate=0.100, error=98.474
# >epoch=137, lrate=0.100, error=98.481
# >epoch=138, lrate=0.100, error=98.487
# >epoch=139, lrate=0.100, error=98.494
# >epoch=140, lrate=0.100, error=98.500
# >epoch=141, lrate=0.100, error=98.506
# >epoch=142, lrate=0.100, error=98.513
# >epoch=143, lrate=0.100, error=98.519
# >epoch=144, lrate=0.100, error=98.525
# >epoch=145, lrate=0.100, error=98.531
# >epoch=146, lrate=0.100, error=98.537
# >epoch=147, lrate=0.100, error=98.543
# >epoch=148, lrate=0.100, error=98.549
# >epoch=149, lrate=0.100, error=98.555
# >epoch=150, lrate=0.100, error=98.561
# >epoch=151, lrate=0.100, error=98.566
# >epoch=152, lrate=0.100, error=98.572
# >epoch=153, lrate=0.100, error=98.578
# >epoch=154, lrate=0.100, error=98.583
# >epoch=155, lrate=0.100, error=98.589
# >epoch=156, lrate=0.100, error=98.595
# >epoch=157, lrate=0.100, error=98.600
# >epoch=158, lrate=0.100, error=98.606
# >epoch=159, lrate=0.100, error=98.611
# >epoch=160, lrate=0.100, error=98.616
# >epoch=161, lrate=0.100, error=98.622
# >epoch=162, lrate=0.100, error=98.627
# >epoch=163, lrate=0.100, error=98.632
# >epoch=164, lrate=0.100, error=98.637
# >epoch=165, lrate=0.100, error=98.642
# >epoch=166, lrate=0.100, error=98.648
# >epoch=167, lrate=0.100, error=98.653
# >epoch=168, lrate=0.100, error=98.658
# >epoch=169, lrate=0.100, error=98.663
# >epoch=170, lrate=0.100, error=98.668
# >epoch=171, lrate=0.100, error=98.672
# >epoch=172, lrate=0.100, error=98.677
# >epoch=173, lrate=0.100, error=98.682
# >epoch=174, lrate=0.100, error=98.687
# >epoch=175, lrate=0.100, error=98.692
# >epoch=176, lrate=0.100, error=98.696
# >epoch=177, lrate=0.100, error=98.701
# >epoch=178, lrate=0.100, error=98.706
# >epoch=179, lrate=0.100, error=98.710
# >epoch=180, lrate=0.100, error=98.715
# >epoch=181, lrate=0.100, error=98.719
# >epoch=182, lrate=0.100, error=98.724
# >epoch=183, lrate=0.100, error=98.728
# >epoch=184, lrate=0.100, error=98.733
# >epoch=185, lrate=0.100, error=98.737
# >epoch=186, lrate=0.100, error=98.741
# >epoch=187, lrate=0.100, error=98.746
# >epoch=188, lrate=0.100, error=98.750
# >epoch=189, lrate=0.100, error=98.754
# >epoch=190, lrate=0.100, error=98.758
# >epoch=191, lrate=0.100, error=98.762
# >epoch=192, lrate=0.100, error=98.767
# >epoch=193, lrate=0.100, error=98.771
# >epoch=194, lrate=0.100, error=98.775
# >epoch=195, lrate=0.100, error=98.779
# >epoch=196, lrate=0.100, error=98.783
# >epoch=197, lrate=0.100, error=98.787
# >epoch=198, lrate=0.100, error=98.791
# >epoch=199, lrate=0.100, error=98.795
# >epoch=200, lrate=0.100, error=98.799
# >epoch=201, lrate=0.100, error=98.802
# >epoch=202, lrate=0.100, error=98.806
# >epoch=203, lrate=0.100, error=98.810
# >epoch=204, lrate=0.100, error=98.814
# >epoch=205, lrate=0.100, error=98.818
# >epoch=206, lrate=0.100, error=98.821
# >epoch=207, lrate=0.100, error=98.825
# >epoch=208, lrate=0.100, error=98.829
# >epoch=209, lrate=0.100, error=98.832
# >epoch=210, lrate=0.100, error=98.836
# >epoch=211, lrate=0.100, error=98.839
# >epoch=212, lrate=0.100, error=98.843
# >epoch=213, lrate=0.100, error=98.846
# >epoch=214, lrate=0.100, error=98.850
# >epoch=215, lrate=0.100, error=98.853
# >epoch=216, lrate=0.100, error=98.857
# >epoch=217, lrate=0.100, error=98.860
# >epoch=218, lrate=0.100, error=98.864
# >epoch=219, lrate=0.100, error=98.867
# >epoch=220, lrate=0.100, error=98.870
# >epoch=221, lrate=0.100, error=98.874
# >epoch=222, lrate=0.100, error=98.877
# >epoch=223, lrate=0.100, error=98.880
# >epoch=224, lrate=0.100, error=98.884
# >epoch=225, lrate=0.100, error=98.887
# >epoch=226, lrate=0.100, error=98.890
# >epoch=227, lrate=0.100, error=98.893
# >epoch=228, lrate=0.100, error=98.896
# >epoch=229, lrate=0.100, error=98.899
# >epoch=230, lrate=0.100, error=98.903
# >epoch=231, lrate=0.100, error=98.906
# >epoch=232, lrate=0.100, error=98.909
# >epoch=233, lrate=0.100, error=98.912
# >epoch=234, lrate=0.100, error=98.915
# >epoch=235, lrate=0.100, error=98.918
# >epoch=236, lrate=0.100, error=98.921
# >epoch=237, lrate=0.100, error=98.924
# >epoch=238, lrate=0.100, error=98.927
# >epoch=239, lrate=0.100, error=98.929
# >epoch=240, lrate=0.100, error=98.932
# >epoch=241, lrate=0.100, error=98.935
# >epoch=242, lrate=0.100, error=98.938
# >epoch=243, lrate=0.100, error=98.941
# >epoch=244, lrate=0.100, error=98.943
# >epoch=245, lrate=0.100, error=98.946
# >epoch=246, lrate=0.100, error=98.949
# >epoch=247, lrate=0.100, error=98.952
# >epoch=248, lrate=0.100, error=98.954
# >epoch=249, lrate=0.100, error=98.957
# >epoch=250, lrate=0.100, error=98.960
# >epoch=251, lrate=0.100, error=98.962
# >epoch=252, lrate=0.100, error=98.965
# >epoch=253, lrate=0.100, error=98.967
# >epoch=254, lrate=0.100, error=98.970
# >epoch=255, lrate=0.100, error=98.972
# >epoch=256, lrate=0.100, error=98.975
# >epoch=257, lrate=0.100, error=98.977
# >epoch=258, lrate=0.100, error=98.979
# >epoch=259, lrate=0.100, error=98.982
# >epoch=260, lrate=0.100, error=98.984
# >epoch=261, lrate=0.100, error=98.986
# >epoch=262, lrate=0.100, error=98.989
# >epoch=263, lrate=0.100, error=98.991
# >epoch=264, lrate=0.100, error=98.993
# >epoch=265, lrate=0.100, error=98.995
# >epoch=266, lrate=0.100, error=98.997
# >epoch=267, lrate=0.100, error=98.999
# >epoch=268, lrate=0.100, error=99.001
# >epoch=269, lrate=0.100, error=99.003
# >epoch=270, lrate=0.100, error=99.005
# >epoch=271, lrate=0.100, error=99.006
# >epoch=272, lrate=0.100, error=99.008
# >epoch=273, lrate=0.100, error=99.010
# >epoch=274, lrate=0.100, error=99.011
# >epoch=275, lrate=0.100, error=99.013
# >epoch=276, lrate=0.100, error=99.014
# >epoch=277, lrate=0.100, error=99.015
# >epoch=278, lrate=0.100, error=99.016
# >epoch=279, lrate=0.100, error=99.017
# >epoch=280, lrate=0.100, error=99.018
# >epoch=281, lrate=0.100, error=99.019
# >epoch=282, lrate=0.100, error=99.020
# >epoch=283, lrate=0.100, error=99.021
# >epoch=284, lrate=0.100, error=99.021
# >epoch=285, lrate=0.100, error=99.021
# >epoch=286, lrate=0.100, error=99.021
# >epoch=287, lrate=0.100, error=99.021
# >epoch=288, lrate=0.100, error=99.021
# >epoch=289, lrate=0.100, error=99.021
# >epoch=290, lrate=0.100, error=99.020
# >epoch=291, lrate=0.100, error=99.019
# >epoch=292, lrate=0.100, error=99.018
# >epoch=293, lrate=0.100, error=99.017
# >epoch=294, lrate=0.100, error=99.015
# >epoch=295, lrate=0.100, error=99.013
# >epoch=296, lrate=0.100, error=99.010
# >epoch=297, lrate=0.100, error=99.008
# >epoch=298, lrate=0.100, error=99.004
# >epoch=299, lrate=0.100, error=99.001
# >epoch=300, lrate=0.100, error=98.997
# >epoch=301, lrate=0.100, error=98.992
# >epoch=302, lrate=0.100, error=98.987
# >epoch=303, lrate=0.100, error=98.981
# >epoch=304, lrate=0.100, error=98.975
# >epoch=305, lrate=0.100, error=98.968
# >epoch=306, lrate=0.100, error=98.960
# >epoch=307, lrate=0.100, error=98.951
# >epoch=308, lrate=0.100, error=98.941
# >epoch=309, lrate=0.100, error=98.931
# >epoch=310, lrate=0.100, error=98.919
# >epoch=311, lrate=0.100, error=98.906
# >epoch=312, lrate=0.100, error=98.892
# >epoch=313, lrate=0.100, error=98.877
# >epoch=314, lrate=0.100, error=98.860
# >epoch=315, lrate=0.100, error=98.842
# >epoch=316, lrate=0.100, error=98.821
# >epoch=317, lrate=0.100, error=98.799
# >epoch=318, lrate=0.100, error=98.775
# >epoch=319, lrate=0.100, error=98.748
# >epoch=320, lrate=0.100, error=98.719
# >epoch=321, lrate=0.100, error=98.687
# >epoch=322, lrate=0.100, error=98.652
# >epoch=323, lrate=0.100, error=98.614
# >epoch=324, lrate=0.100, error=98.572
# >epoch=325, lrate=0.100, error=98.527
# >epoch=326, lrate=0.100, error=98.476
# >epoch=327, lrate=0.100, error=98.421
# >epoch=328, lrate=0.100, error=98.361
# >epoch=329, lrate=0.100, error=98.295
# >epoch=330, lrate=0.100, error=98.222
# >epoch=331, lrate=0.100, error=98.142
# >epoch=332, lrate=0.100, error=98.054
# >epoch=333, lrate=0.100, error=97.957
# >epoch=334, lrate=0.100, error=97.850
# >epoch=335, lrate=0.100, error=97.732
# >epoch=336, lrate=0.100, error=97.601
# >epoch=337, lrate=0.100, error=97.456
# >epoch=338, lrate=0.100, error=97.295
# >epoch=339, lrate=0.100, error=97.115
# >epoch=340, lrate=0.100, error=96.915
# >epoch=341, lrate=0.100, error=96.690
# >epoch=342, lrate=0.100, error=96.438
# >epoch=343, lrate=0.100, error=96.153
# >epoch=344, lrate=0.100, error=95.831
# >epoch=345, lrate=0.100, error=95.465
# >epoch=346, lrate=0.100, error=95.047
# >epoch=347, lrate=0.100, error=94.569
# >epoch=348, lrate=0.100, error=94.019
# >epoch=349, lrate=0.100, error=93.383
# >epoch=350, lrate=0.100, error=92.647
# >epoch=351, lrate=0.100, error=91.792
# >epoch=352, lrate=0.100, error=90.797
# >epoch=353, lrate=0.100, error=89.638
# >epoch=354, lrate=0.100, error=88.292
# >epoch=355, lrate=0.100, error=86.736
# >epoch=356, lrate=0.100, error=84.951
# >epoch=357, lrate=0.100, error=82.932
# >epoch=358, lrate=0.100, error=80.686
# >epoch=359, lrate=0.100, error=78.244
# >epoch=360, lrate=0.100, error=75.657
# >epoch=361, lrate=0.100, error=72.998
# >epoch=362, lrate=0.100, error=70.345
# >epoch=363, lrate=0.100, error=67.773
# >epoch=364, lrate=0.100, error=65.341
# >epoch=365, lrate=0.100, error=63.090
# >epoch=366, lrate=0.100, error=61.036
# >epoch=367, lrate=0.100, error=59.183
# >epoch=368, lrate=0.100, error=57.519
# >epoch=369, lrate=0.100, error=56.031
# >epoch=370, lrate=0.100, error=54.701
# >epoch=371, lrate=0.100, error=53.510
# >epoch=372, lrate=0.100, error=52.442
# >epoch=373, lrate=0.100, error=51.481
# >epoch=374, lrate=0.100, error=50.615
# >epoch=375, lrate=0.100, error=49.831
# >epoch=376, lrate=0.100, error=49.119
# >epoch=377, lrate=0.100, error=48.471
# >epoch=378, lrate=0.100, error=47.878
# >epoch=379, lrate=0.100, error=47.334
# >epoch=380, lrate=0.100, error=46.833
# >epoch=381, lrate=0.100, error=46.369
# >epoch=382, lrate=0.100, error=45.940
# >epoch=383, lrate=0.100, error=45.540
# >epoch=384, lrate=0.100, error=45.167
# >epoch=385, lrate=0.100, error=44.817
# >epoch=386, lrate=0.100, error=44.489
# >epoch=387, lrate=0.100, error=44.180
# >epoch=388, lrate=0.100, error=43.887
# >epoch=389, lrate=0.100, error=43.610
# >epoch=390, lrate=0.100, error=43.347
# >epoch=391, lrate=0.100, error=43.096
# >epoch=392, lrate=0.100, error=42.856
# >epoch=393, lrate=0.100, error=42.626
# >epoch=394, lrate=0.100, error=42.405
# >epoch=395, lrate=0.100, error=42.191
# >epoch=396, lrate=0.100, error=41.984
# >epoch=397, lrate=0.100, error=41.783
# >epoch=398, lrate=0.100, error=41.586
# >epoch=399, lrate=0.100, error=41.392
# >epoch=400, lrate=0.100, error=41.200
# >epoch=401, lrate=0.100, error=41.009
# >epoch=402, lrate=0.100, error=40.817
# >epoch=403, lrate=0.100, error=40.622
# >epoch=404, lrate=0.100, error=40.423
# >epoch=405, lrate=0.100, error=40.218
# >epoch=406, lrate=0.100, error=40.004
# >epoch=407, lrate=0.100, error=39.780
# >epoch=408, lrate=0.100, error=39.542
# >epoch=409, lrate=0.100, error=39.288
# >epoch=410, lrate=0.100, error=39.016
# >epoch=411, lrate=0.100, error=38.721
# >epoch=412, lrate=0.100, error=38.402
# >epoch=413, lrate=0.100, error=38.055
# >epoch=414, lrate=0.100, error=37.678
# >epoch=415, lrate=0.100, error=37.269
# >epoch=416, lrate=0.100, error=36.826
# >epoch=417, lrate=0.100, error=36.348
# >epoch=418, lrate=0.100, error=35.835
# >epoch=419, lrate=0.100, error=35.286
# >epoch=420, lrate=0.100, error=34.703
# >epoch=421, lrate=0.100, error=34.086
# >epoch=422, lrate=0.100, error=33.438
# >epoch=423, lrate=0.100, error=32.759
# >epoch=424, lrate=0.100, error=32.054
# >epoch=425, lrate=0.100, error=31.324
# >epoch=426, lrate=0.100, error=30.572
# >epoch=427, lrate=0.100, error=29.803
# >epoch=428, lrate=0.100, error=29.018
# >epoch=429, lrate=0.100, error=28.223
# >epoch=430, lrate=0.100, error=27.420
# >epoch=431, lrate=0.100, error=26.613
# >epoch=432, lrate=0.100, error=25.806
# >epoch=433, lrate=0.100, error=25.002
# >epoch=434, lrate=0.100, error=24.205
# >epoch=435, lrate=0.100, error=23.419
# >epoch=436, lrate=0.100, error=22.645
# >epoch=437, lrate=0.100, error=21.888
# >epoch=438, lrate=0.100, error=21.148
# >epoch=439, lrate=0.100, error=20.429
# >epoch=440, lrate=0.100, error=19.731
# >epoch=441, lrate=0.100, error=19.057
# >epoch=442, lrate=0.100, error=18.408
# >epoch=443, lrate=0.100, error=17.783
# >epoch=444, lrate=0.100, error=17.184
# >epoch=445, lrate=0.100, error=16.610
# >epoch=446, lrate=0.100, error=16.062
# >epoch=447, lrate=0.100, error=15.539
# >epoch=448, lrate=0.100, error=15.041
# >epoch=449, lrate=0.100, error=14.567
# >epoch=450, lrate=0.100, error=14.116
# >epoch=451, lrate=0.100, error=13.688
# >epoch=452, lrate=0.100, error=13.282
# >epoch=453, lrate=0.100, error=12.896
# >epoch=454, lrate=0.100, error=12.530
# >epoch=455, lrate=0.100, error=12.183
# >epoch=456, lrate=0.100, error=11.855
# >epoch=457, lrate=0.100, error=11.543
# >epoch=458, lrate=0.100, error=11.247
# >epoch=459, lrate=0.100, error=10.966
# >epoch=460, lrate=0.100, error=10.700
# >epoch=461, lrate=0.100, error=10.447
# >epoch=462, lrate=0.100, error=10.208
# >epoch=463, lrate=0.100, error=9.980
# >epoch=464, lrate=0.100, error=9.763
# >epoch=465, lrate=0.100, error=9.557
# >epoch=466, lrate=0.100, error=9.361
# >epoch=467, lrate=0.100, error=9.175
# >epoch=468, lrate=0.100, error=8.997
# >epoch=469, lrate=0.100, error=8.828
# >epoch=470, lrate=0.100, error=8.666
# >epoch=471, lrate=0.100, error=8.512
# >epoch=472, lrate=0.100, error=8.365
# >epoch=473, lrate=0.100, error=8.224
# >epoch=474, lrate=0.100, error=8.090
# >epoch=475, lrate=0.100, error=7.961
# >epoch=476, lrate=0.100, error=7.838
# >epoch=477, lrate=0.100, error=7.721
# >epoch=478, lrate=0.100, error=7.608
# >epoch=479, lrate=0.100, error=7.499
# >epoch=480, lrate=0.100, error=7.396
# >epoch=481, lrate=0.100, error=7.296
# >epoch=482, lrate=0.100, error=7.200
# >epoch=483, lrate=0.100, error=7.108
# >epoch=484, lrate=0.100, error=7.020
# >epoch=485, lrate=0.100, error=6.935
# >epoch=486, lrate=0.100, error=6.853
# >epoch=487, lrate=0.100, error=6.775
# >epoch=488, lrate=0.100, error=6.699
# >epoch=489, lrate=0.100, error=6.626
# >epoch=490, lrate=0.100, error=6.555
# >epoch=491, lrate=0.100, error=6.487
# >epoch=492, lrate=0.100, error=6.422
# >epoch=493, lrate=0.100, error=6.359
# >epoch=494, lrate=0.100, error=6.298
# >epoch=495, lrate=0.100, error=6.239
# >epoch=496, lrate=0.100, error=6.182
# >epoch=497, lrate=0.100, error=6.127
# >epoch=498, lrate=0.100, error=6.074
# >epoch=499, lrate=0.100, error=6.022
