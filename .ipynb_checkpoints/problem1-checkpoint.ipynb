# %%
import random
from math import exp
import matplotlib.pyplot as plt
# process data label as 0, 1, 2 for training
def loadDataset(dataset): 
    newdata = []
    for x in range(len(dataset)-1):
        for i in range(0,len(dataset[x]),4):
            if dataset[x][i] == "I": # encounter labels, change it
                if dataset[x][-3:-1] == "sa": # Iris-setosa
                    newdata.append(0)
                elif dataset[x][-2:-1] == "r": # Iris-versicolor
                    newdata.append(1)
                elif dataset[x][-3:-1] == "ca": # Iris-virginica
                    newdata.append(2) 
                break
            else:
                attribute = float(dataset[x][i:i+3])
                newdata.append(attribute)
        trainingSet.append(newdata)       
        newdata = [] # clear the package
    return trainingSet

# find the range of data to do normalize
def dataset_minmax(dataset): # zip a(1,2,3) , b(4,5,6) to [(1,4), (2,5), (3,6)] 
    minmax = list()
    stats = [[min(column), max(column)] for column in zip(*dataset)] # unzip the file
    return stats

# rescale data to range 0~1
def normalize_data(dataset, minmax):
    for row in dataset:
        for i in range(len(row)-1):
            row[i] = (row[i] - minmax[i][0]) / (minmax[i][1] - minmax[i][0])

# calculate neuron activation for an input
def activate(weights, inputs):
    activation = weights[-1]
    for i in range(len(weights)-1):
        activation += weights[i] * inputs[i]
    return activation

# transfer neuron activation 
def transfer(activation):
    return 1.0 / (1.0 + exp(-activation))

# calculate the derivative of an neuron output
def transfer_derivative(output):
    return output * (1.0 - output)

#forward propagate input to a network output
def forward_propagate(network, row):
    inputs = row
    for layer in network:
        new_inputs = []
        for neuron in layer:
            activation = activate(neuron['weights'], inputs)
            neuron['output'] = transfer(activation)
            new_inputs.append(neuron['output'])
        inputs = new_inputs # keep updating the neurons
    return inputs

# backpropagate error and sotre in neurons
def backward_propagate_error(network, expected): 
    for i in reversed(range(len(network))):
        layer = network[i]
        errors = list()
        if i != len(network)-1:
            for j in range(len(layer)): # hidden
                error = 0.0
                for neuron in network[i+1]:
                    error += (neuron['weights'][j] * neuron['delta'])
                errors.append(error) 
        else:
            for j in range(len(layer)): # output
                neuron = layer[j]
                errors.append(expected[j] - neuron['output'])
        for j in range(len(layer)):
            neuron = layer[j]
            neuron['delta'] = errors[j] * transfer_derivative(neuron['output'])

# update network weights with error
def update_weights(network, row, learning_rate):
    for i in range(len(network)):
        inputs = row[:-1]
        if i != 0:
            inputs = [neuron['output'] for neuron in network[i-1]]
        for neuron in network[i]:
            for j in range(len(inputs)):
                neuron['weights'][j] += learning_rate * neuron['delta'] * inputs[j]
            neuron['weights'][-1] += learning_rate * neuron['delta']

def train_network(network, train, learning_rate, n_epoch, n_outputs):
    SE = []
    EPOCH = [i for i in range(n_epoch)]
    for epoch in range(n_epoch):
        sum_error = 0
        for row in train:
            outputs = forward_propagate(network, row)
            expected = [0 for i in range(n_outputs)]
            expected[row[-1]] = 1 # one hot encoding !!!
            sum_error += sum([(expected[i]-outputs[i])**2 for i in range(len(expected))])
            backward_propagate_error(network, expected)
            update_weights(network, row, learning_rate)
        print('>epoch=%d, lrate=%.3f, error=%.3f' % (epoch, learning_rate, sum_error))
        SE.append(sum_error)

    plt.plot(EPOCH, SE, 'r')
    plt.ylabel("Sum of error")
    plt.xlabel("Number of epochs")
    plt.show()


def init_network(n_inputs, n_hidden, n_outputs): 
# create n_hidden neurons and each neuron in the hidden layer has n_inputs + 1 weights
    network = list()
    hidden_layer1 = [{'weights': [(random.random()-0.5)/5.0 for i in range(n_inputs + 1)]} for i in range(n_hidden)]
    network.append(hidden_layer1) # 4 neurons with 4 input weights plus the bias
    hidden_layer2 = [{'weights': [(random.random()-0.5)/5.0 for i in range(n_inputs + 1)]} for i in range(n_hidden)]
    network.append(hidden_layer2)
    #for layer in network:
        #print(layer)
    output_layer = [{'weights': [(random.random()-0.5)/5.0 for i in range(n_hidden + 1)]} for i in range(n_outputs)]
    #print("out",hidden_layer)
    network.append(output_layer) # 3 neurons with 4 input weights plus the bias
    #for layer in network:
     #   print(layer)
    return network

# make a prediction with a network
# It returns the index in the network output that has the largest probability. 
# Assuming that class values have been converted to integers starting at 0. [0,1,2]
def predict(network, row):
    outputs = forward_propagate(network, row)
    return outputs.index(max(outputs))

# backpropagation with stochastic gradient descent
def back_propagate(train, learning_rate, n_epoch, n_hidden):
    n_inputs = len(train[0]) - 1
    n_outputs = len(set([row[-1] for row in train]))
    network = init_network(n_inputs, n_hidden, n_outputs)
    train_network(network, train, learning_rate, n_epoch, n_outputs)

# %%
trainingSet=[]
testSet=[]

f = open('iris.data.txt', "r")
lines = f.readlines()
dataset = list(lines)
trainingSet = loadDataset(dataset)

# %%
# normalize inputs

minmax = dataset_minmax(trainingSet)
normalize_data(trainingSet, minmax)

learning_rate = 0.1
n_epoch = 500
n_hidden = 4 # neuron per layer

back_propagate(trainingSet, learning_rate, n_epoch, n_hidden)
# Out:
# >epoch=0, lrate=0.100, error=93.363
# >epoch=1, lrate=0.100, error=95.612
# >epoch=2, lrate=0.100, error=96.904
# >epoch=3, lrate=0.100, error=97.239
# >epoch=4, lrate=0.100, error=97.334
# >epoch=5, lrate=0.100, error=97.369
# >epoch=6, lrate=0.100, error=97.389
# >epoch=7, lrate=0.100, error=97.406
# >epoch=8, lrate=0.100, error=97.421
# >epoch=9, lrate=0.100, error=97.437
# >epoch=10, lrate=0.100, error=97.452
# >epoch=11, lrate=0.100, error=97.467
# >epoch=12, lrate=0.100, error=97.481
# >epoch=13, lrate=0.100, error=97.496
# >epoch=14, lrate=0.100, error=97.511
# >epoch=15, lrate=0.100, error=97.525
# >epoch=16, lrate=0.100, error=97.540
# >epoch=17, lrate=0.100, error=97.554
# >epoch=18, lrate=0.100, error=97.568
# >epoch=19, lrate=0.100, error=97.582
# >epoch=20, lrate=0.100, error=97.596
# >epoch=21, lrate=0.100, error=97.610
# >epoch=22, lrate=0.100, error=97.623
# >epoch=23, lrate=0.100, error=97.637
# >epoch=24, lrate=0.100, error=97.650
# >epoch=25, lrate=0.100, error=97.664
# >epoch=26, lrate=0.100, error=97.677
# >epoch=27, lrate=0.100, error=97.690
# >epoch=28, lrate=0.100, error=97.703
# >epoch=29, lrate=0.100, error=97.716
# >epoch=30, lrate=0.100, error=97.729
# >epoch=31, lrate=0.100, error=97.742
# >epoch=32, lrate=0.100, error=97.755
# >epoch=33, lrate=0.100, error=97.767
# >epoch=34, lrate=0.100, error=97.780
# >epoch=35, lrate=0.100, error=97.792
# >epoch=36, lrate=0.100, error=97.804
# >epoch=37, lrate=0.100, error=97.817
# >epoch=38, lrate=0.100, error=97.829
# >epoch=39, lrate=0.100, error=97.841
# >epoch=40, lrate=0.100, error=97.853
# >epoch=41, lrate=0.100, error=97.864
# >epoch=42, lrate=0.100, error=97.876
# >epoch=43, lrate=0.100, error=97.888
# >epoch=44, lrate=0.100, error=97.899
# >epoch=45, lrate=0.100, error=97.911
# >epoch=46, lrate=0.100, error=97.922
# >epoch=47, lrate=0.100, error=97.933
# >epoch=48, lrate=0.100, error=97.945
# >epoch=49, lrate=0.100, error=97.956
# >epoch=50, lrate=0.100, error=97.967
# >epoch=51, lrate=0.100, error=97.978
# >epoch=52, lrate=0.100, error=97.988
# >epoch=53, lrate=0.100, error=97.999
# >epoch=54, lrate=0.100, error=98.010
# >epoch=55, lrate=0.100, error=98.020
# >epoch=56, lrate=0.100, error=98.031
# >epoch=57, lrate=0.100, error=98.041
# >epoch=58, lrate=0.100, error=98.051
# >epoch=59, lrate=0.100, error=98.062
# >epoch=60, lrate=0.100, error=98.072
# >epoch=61, lrate=0.100, error=98.082
# >epoch=62, lrate=0.100, error=98.092
# >epoch=63, lrate=0.100, error=98.101
# >epoch=64, lrate=0.100, error=98.111
# >epoch=65, lrate=0.100, error=98.121
# >epoch=66, lrate=0.100, error=98.131
# >epoch=67, lrate=0.100, error=98.140
# >epoch=68, lrate=0.100, error=98.149
# >epoch=69, lrate=0.100, error=98.159
# >epoch=70, lrate=0.100, error=98.168
# >epoch=71, lrate=0.100, error=98.177
# >epoch=72, lrate=0.100, error=98.186
# >epoch=73, lrate=0.100, error=98.195
# >epoch=74, lrate=0.100, error=98.204
# >epoch=75, lrate=0.100, error=98.213
# >epoch=76, lrate=0.100, error=98.222
# >epoch=77, lrate=0.100, error=98.231
# >epoch=78, lrate=0.100, error=98.239
# >epoch=79, lrate=0.100, error=98.248
# >epoch=80, lrate=0.100, error=98.257
# >epoch=81, lrate=0.100, error=98.265
# >epoch=82, lrate=0.100, error=98.273
# >epoch=83, lrate=0.100, error=98.282
# >epoch=84, lrate=0.100, error=98.290
# >epoch=85, lrate=0.100, error=98.298
# >epoch=86, lrate=0.100, error=98.306
# >epoch=87, lrate=0.100, error=98.314
# >epoch=88, lrate=0.100, error=98.322
# >epoch=89, lrate=0.100, error=98.329
# >epoch=90, lrate=0.100, error=98.337
# >epoch=91, lrate=0.100, error=98.345
# >epoch=92, lrate=0.100, error=98.352
# >epoch=93, lrate=0.100, error=98.360
# >epoch=94, lrate=0.100, error=98.367
# >epoch=95, lrate=0.100, error=98.375
# >epoch=96, lrate=0.100, error=98.382
# >epoch=97, lrate=0.100, error=98.389
# >epoch=98, lrate=0.100, error=98.397
# >epoch=99, lrate=0.100, error=98.404
# >epoch=100, lrate=0.100, error=98.411
# >epoch=101, lrate=0.100, error=98.418
# >epoch=102, lrate=0.100, error=98.425
# >epoch=103, lrate=0.100, error=98.431
# >epoch=104, lrate=0.100, error=98.438
# >epoch=105, lrate=0.100, error=98.445
# >epoch=106, lrate=0.100, error=98.451
# >epoch=107, lrate=0.100, error=98.458
# >epoch=108, lrate=0.100, error=98.465
# >epoch=109, lrate=0.100, error=98.471
# >epoch=110, lrate=0.100, error=98.477
# >epoch=111, lrate=0.100, error=98.484
# >epoch=112, lrate=0.100, error=98.490
# >epoch=113, lrate=0.100, error=98.496
# >epoch=114, lrate=0.100, error=98.502
# >epoch=115, lrate=0.100, error=98.508
# >epoch=116, lrate=0.100, error=98.514
# >epoch=117, lrate=0.100, error=98.520
# >epoch=118, lrate=0.100, error=98.526
# >epoch=119, lrate=0.100, error=98.532
# >epoch=120, lrate=0.100, error=98.538
# >epoch=121, lrate=0.100, error=98.543
# >epoch=122, lrate=0.100, error=98.549
# >epoch=123, lrate=0.100, error=98.555
# >epoch=124, lrate=0.100, error=98.560
# >epoch=125, lrate=0.100, error=98.566
# >epoch=126, lrate=0.100, error=98.571
# >epoch=127, lrate=0.100, error=98.576
# >epoch=128, lrate=0.100, error=98.582
# >epoch=129, lrate=0.100, error=98.587
# >epoch=130, lrate=0.100, error=98.592
# >epoch=131, lrate=0.100, error=98.597
# >epoch=132, lrate=0.100, error=98.602
# >epoch=133, lrate=0.100, error=98.608
# >epoch=134, lrate=0.100, error=98.613
# >epoch=135, lrate=0.100, error=98.617
# >epoch=136, lrate=0.100, error=98.622
# >epoch=137, lrate=0.100, error=98.627
# >epoch=138, lrate=0.100, error=98.632
# >epoch=139, lrate=0.100, error=98.637
# >epoch=140, lrate=0.100, error=98.641
# >epoch=141, lrate=0.100, error=98.646
# >epoch=142, lrate=0.100, error=98.650
# >epoch=143, lrate=0.100, error=98.655
# >epoch=144, lrate=0.100, error=98.659
# >epoch=145, lrate=0.100, error=98.664
# >epoch=146, lrate=0.100, error=98.668
# >epoch=147, lrate=0.100, error=98.673
# >epoch=148, lrate=0.100, error=98.677
# >epoch=149, lrate=0.100, error=98.681
# >epoch=150, lrate=0.100, error=98.685
# >epoch=151, lrate=0.100, error=98.689
# >epoch=152, lrate=0.100, error=98.693
# >epoch=153, lrate=0.100, error=98.697
# >epoch=154, lrate=0.100, error=98.701
# >epoch=155, lrate=0.100, error=98.705
# >epoch=156, lrate=0.100, error=98.709
# >epoch=157, lrate=0.100, error=98.712
# >epoch=158, lrate=0.100, error=98.716
# >epoch=159, lrate=0.100, error=98.720
# >epoch=160, lrate=0.100, error=98.723
# >epoch=161, lrate=0.100, error=98.727
# >epoch=162, lrate=0.100, error=98.730
# >epoch=163, lrate=0.100, error=98.734
# >epoch=164, lrate=0.100, error=98.737
# >epoch=165, lrate=0.100, error=98.740
# >epoch=166, lrate=0.100, error=98.743
# >epoch=167, lrate=0.100, error=98.746
# >epoch=168, lrate=0.100, error=98.749
# >epoch=169, lrate=0.100, error=98.752
# >epoch=170, lrate=0.100, error=98.755
# >epoch=171, lrate=0.100, error=98.758
# >epoch=172, lrate=0.100, error=98.760
# >epoch=173, lrate=0.100, error=98.763
# >epoch=174, lrate=0.100, error=98.765
# >epoch=175, lrate=0.100, error=98.768
# >epoch=176, lrate=0.100, error=98.770
# >epoch=177, lrate=0.100, error=98.772
# >epoch=178, lrate=0.100, error=98.774
# >epoch=179, lrate=0.100, error=98.776
# >epoch=180, lrate=0.100, error=98.778
# >epoch=181, lrate=0.100, error=98.779
# >epoch=182, lrate=0.100, error=98.781
# >epoch=183, lrate=0.100, error=98.782
# >epoch=184, lrate=0.100, error=98.783
# >epoch=185, lrate=0.100, error=98.784
# >epoch=186, lrate=0.100, error=98.785
# >epoch=187, lrate=0.100, error=98.785
# >epoch=188, lrate=0.100, error=98.786
# >epoch=189, lrate=0.100, error=98.786
# >epoch=190, lrate=0.100, error=98.785
# >epoch=191, lrate=0.100, error=98.785
# >epoch=192, lrate=0.100, error=98.784
# >epoch=193, lrate=0.100, error=98.783
# >epoch=194, lrate=0.100, error=98.781
# >epoch=195, lrate=0.100, error=98.779
# >epoch=196, lrate=0.100, error=98.777
# >epoch=197, lrate=0.100, error=98.774
# >epoch=198, lrate=0.100, error=98.771
# >epoch=199, lrate=0.100, error=98.767
# >epoch=200, lrate=0.100, error=98.763
# >epoch=201, lrate=0.100, error=98.758
# >epoch=202, lrate=0.100, error=98.752
# >epoch=203, lrate=0.100, error=98.745
# >epoch=204, lrate=0.100, error=98.737
# >epoch=205, lrate=0.100, error=98.729
# >epoch=206, lrate=0.100, error=98.719
# >epoch=207, lrate=0.100, error=98.708
# >epoch=208, lrate=0.100, error=98.696
# >epoch=209, lrate=0.100, error=98.683
# >epoch=210, lrate=0.100, error=98.667
# >epoch=211, lrate=0.100, error=98.650
# >epoch=212, lrate=0.100, error=98.631
# >epoch=213, lrate=0.100, error=98.609
# >epoch=214, lrate=0.100, error=98.585
# >epoch=215, lrate=0.100, error=98.557
# >epoch=216, lrate=0.100, error=98.527
# >epoch=217, lrate=0.100, error=98.492
# >epoch=218, lrate=0.100, error=98.453
# >epoch=219, lrate=0.100, error=98.409
# >epoch=220, lrate=0.100, error=98.359
# >epoch=221, lrate=0.100, error=98.303
# >epoch=222, lrate=0.100, error=98.239
# >epoch=223, lrate=0.100, error=98.167
# >epoch=224, lrate=0.100, error=98.084
# >epoch=225, lrate=0.100, error=97.990
# >epoch=226, lrate=0.100, error=97.882
# >epoch=227, lrate=0.100, error=97.759
# >epoch=228, lrate=0.100, error=97.617
# >epoch=229, lrate=0.100, error=97.453
# >epoch=230, lrate=0.100, error=97.264
# >epoch=231, lrate=0.100, error=97.045
# >epoch=232, lrate=0.100, error=96.790
# >epoch=233, lrate=0.100, error=96.493
# >epoch=234, lrate=0.100, error=96.147
# >epoch=235, lrate=0.100, error=95.741
# >epoch=236, lrate=0.100, error=95.264
# >epoch=237, lrate=0.100, error=94.704
# >epoch=238, lrate=0.100, error=94.045
# >epoch=239, lrate=0.100, error=93.269
# >epoch=240, lrate=0.100, error=92.355
# >epoch=241, lrate=0.100, error=91.283
# >epoch=242, lrate=0.100, error=90.029
# >epoch=243, lrate=0.100, error=88.573
# >epoch=244, lrate=0.100, error=86.899
# >epoch=245, lrate=0.100, error=85.000
# >epoch=246, lrate=0.100, error=82.884
# >epoch=247, lrate=0.100, error=80.577
# >epoch=248, lrate=0.100, error=78.125
# >epoch=249, lrate=0.100, error=75.591
# >epoch=250, lrate=0.100, error=73.046
# >epoch=251, lrate=0.100, error=70.557
# >epoch=252, lrate=0.100, error=68.182
# >epoch=253, lrate=0.100, error=65.959
# >epoch=254, lrate=0.100, error=63.907
# >epoch=255, lrate=0.100, error=62.033
# >epoch=256, lrate=0.100, error=60.331
# >epoch=257, lrate=0.100, error=58.790
# >epoch=258, lrate=0.100, error=57.398
# >epoch=259, lrate=0.100, error=56.141
# >epoch=260, lrate=0.100, error=55.004
# >epoch=261, lrate=0.100, error=53.975
# >epoch=262, lrate=0.100, error=53.042
# >epoch=263, lrate=0.100, error=52.194
# >epoch=264, lrate=0.100, error=51.422
# >epoch=265, lrate=0.100, error=50.717
# >epoch=266, lrate=0.100, error=50.072
# >epoch=267, lrate=0.100, error=49.480
# >epoch=268, lrate=0.100, error=48.935
# >epoch=269, lrate=0.100, error=48.432
# >epoch=270, lrate=0.100, error=47.965
# >epoch=271, lrate=0.100, error=47.531
# >epoch=272, lrate=0.100, error=47.126
# >epoch=273, lrate=0.100, error=46.746
# >epoch=274, lrate=0.100, error=46.390
# >epoch=275, lrate=0.100, error=46.054
# >epoch=276, lrate=0.100, error=45.736
# >epoch=277, lrate=0.100, error=45.434
# >epoch=278, lrate=0.100, error=45.146
# >epoch=279, lrate=0.100, error=44.871
# >epoch=280, lrate=0.100, error=44.608
# >epoch=281, lrate=0.100, error=44.354
# >epoch=282, lrate=0.100, error=44.109
# >epoch=283, lrate=0.100, error=43.872
# >epoch=284, lrate=0.100, error=43.641
# >epoch=285, lrate=0.100, error=43.415
# >epoch=286, lrate=0.100, error=43.194
# >epoch=287, lrate=0.100, error=42.975
# >epoch=288, lrate=0.100, error=42.758
# >epoch=289, lrate=0.100, error=42.542
# >epoch=290, lrate=0.100, error=42.326
# >epoch=291, lrate=0.100, error=42.107
# >epoch=292, lrate=0.100, error=41.886
# >epoch=293, lrate=0.100, error=41.660
# >epoch=294, lrate=0.100, error=41.429
# >epoch=295, lrate=0.100, error=41.190
# >epoch=296, lrate=0.100, error=40.943
# >epoch=297, lrate=0.100, error=40.686
# >epoch=298, lrate=0.100, error=40.417
# >epoch=299, lrate=0.100, error=40.135
# >epoch=300, lrate=0.100, error=39.838
# >epoch=301, lrate=0.100, error=39.526
# >epoch=302, lrate=0.100, error=39.196
# >epoch=303, lrate=0.100, error=38.847
# >epoch=304, lrate=0.100, error=38.478
# >epoch=305, lrate=0.100, error=38.088
# >epoch=306, lrate=0.100, error=37.675
# >epoch=307, lrate=0.100, error=37.237
# >epoch=308, lrate=0.100, error=36.775
# >epoch=309, lrate=0.100, error=36.286
# >epoch=310, lrate=0.100, error=35.771
# >epoch=311, lrate=0.100, error=35.228
# >epoch=312, lrate=0.100, error=34.659
# >epoch=313, lrate=0.100, error=34.062
# >epoch=314, lrate=0.100, error=33.438
# >epoch=315, lrate=0.100, error=32.789
# >epoch=316, lrate=0.100, error=32.116
# >epoch=317, lrate=0.100, error=31.419
# >epoch=318, lrate=0.100, error=30.701
# >epoch=319, lrate=0.100, error=29.964
# >epoch=320, lrate=0.100, error=29.209
# >epoch=321, lrate=0.100, error=28.439
# >epoch=322, lrate=0.100, error=27.658
# >epoch=323, lrate=0.100, error=26.868
# >epoch=324, lrate=0.100, error=26.072
# >epoch=325, lrate=0.100, error=25.275
# >epoch=326, lrate=0.100, error=24.479
# >epoch=327, lrate=0.100, error=23.689
# >epoch=328, lrate=0.100, error=22.909
# >epoch=329, lrate=0.100, error=22.141
# >epoch=330, lrate=0.100, error=21.389
# >epoch=331, lrate=0.100, error=20.656
# >epoch=332, lrate=0.100, error=19.944
# >epoch=333, lrate=0.100, error=19.256
# >epoch=334, lrate=0.100, error=18.592
# >epoch=335, lrate=0.100, error=17.955
# >epoch=336, lrate=0.100, error=17.344
# >epoch=337, lrate=0.100, error=16.761
# >epoch=338, lrate=0.100, error=16.205
# >epoch=339, lrate=0.100, error=15.675
# >epoch=340, lrate=0.100, error=15.172
# >epoch=341, lrate=0.100, error=14.695
# >epoch=342, lrate=0.100, error=14.243
# >epoch=343, lrate=0.100, error=13.815
# >epoch=344, lrate=0.100, error=13.410
# >epoch=345, lrate=0.100, error=13.026
# >epoch=346, lrate=0.100, error=12.664
# >epoch=347, lrate=0.100, error=12.321
# >epoch=348, lrate=0.100, error=11.997
# >epoch=349, lrate=0.100, error=11.690
# >epoch=350, lrate=0.100, error=11.400
# >epoch=351, lrate=0.100, error=11.126
# >epoch=352, lrate=0.100, error=10.866
# >epoch=353, lrate=0.100, error=10.620
# >epoch=354, lrate=0.100, error=10.386
# >epoch=355, lrate=0.100, error=10.165
# >epoch=356, lrate=0.100, error=9.955
# >epoch=357, lrate=0.100, error=9.756
# >epoch=358, lrate=0.100, error=9.567
# >epoch=359, lrate=0.100, error=9.387
# >epoch=360, lrate=0.100, error=9.215
# >epoch=361, lrate=0.100, error=9.052
# >epoch=362, lrate=0.100, error=8.897
# >epoch=363, lrate=0.100, error=8.749
# >epoch=364, lrate=0.100, error=8.608
# >epoch=365, lrate=0.100, error=8.474
# >epoch=366, lrate=0.100, error=8.345
# >epoch=367, lrate=0.100, error=8.222
# >epoch=368, lrate=0.100, error=8.104
# >epoch=369, lrate=0.100, error=7.992
# >epoch=370, lrate=0.100, error=7.884
# >epoch=371, lrate=0.100, error=7.781
# >epoch=372, lrate=0.100, error=7.682
# >epoch=373, lrate=0.100, error=7.587
# >epoch=374, lrate=0.100, error=7.496
# >epoch=375, lrate=0.100, error=7.408
# >epoch=376, lrate=0.100, error=7.324
# >epoch=377, lrate=0.100, error=7.243
# >epoch=378, lrate=0.100, error=7.166
# >epoch=379, lrate=0.100, error=7.091
# >epoch=380, lrate=0.100, error=7.018
# >epoch=381, lrate=0.100, error=6.949
# >epoch=382, lrate=0.100, error=6.882
# >epoch=383, lrate=0.100, error=6.817
# >epoch=384, lrate=0.100, error=6.755
# >epoch=385, lrate=0.100, error=6.695
# >epoch=386, lrate=0.100, error=6.637
# >epoch=387, lrate=0.100, error=6.581
# >epoch=388, lrate=0.100, error=6.526
# >epoch=389, lrate=0.100, error=6.474
# >epoch=390, lrate=0.100, error=6.423
# >epoch=391, lrate=0.100, error=6.374
# >epoch=392, lrate=0.100, error=6.326
# >epoch=393, lrate=0.100, error=6.280
# >epoch=394, lrate=0.100, error=6.236
# >epoch=395, lrate=0.100, error=6.192
# >epoch=396, lrate=0.100, error=6.151
# >epoch=397, lrate=0.100, error=6.110
# >epoch=398, lrate=0.100, error=6.070
# >epoch=399, lrate=0.100, error=6.032
# >epoch=400, lrate=0.100, error=5.995
# >epoch=401, lrate=0.100, error=5.959
# >epoch=402, lrate=0.100, error=5.924
# >epoch=403, lrate=0.100, error=5.890
# >epoch=404, lrate=0.100, error=5.857
# >epoch=405, lrate=0.100, error=5.825
# >epoch=406, lrate=0.100, error=5.794
# >epoch=407, lrate=0.100, error=5.763
# >epoch=408, lrate=0.100, error=5.734
# >epoch=409, lrate=0.100, error=5.705
# >epoch=410, lrate=0.100, error=5.677
# >epoch=411, lrate=0.100, error=5.650
# >epoch=412, lrate=0.100, error=5.623
# >epoch=413, lrate=0.100, error=5.597
# >epoch=414, lrate=0.100, error=5.572
# >epoch=415, lrate=0.100, error=5.548
# >epoch=416, lrate=0.100, error=5.524
# >epoch=417, lrate=0.100, error=5.501
# >epoch=418, lrate=0.100, error=5.478
# >epoch=419, lrate=0.100, error=5.456
# >epoch=420, lrate=0.100, error=5.434
# >epoch=421, lrate=0.100, error=5.413
# >epoch=422, lrate=0.100, error=5.393
# >epoch=423, lrate=0.100, error=5.373
# >epoch=424, lrate=0.100, error=5.353
# >epoch=425, lrate=0.100, error=5.334
# >epoch=426, lrate=0.100, error=5.316
# >epoch=427, lrate=0.100, error=5.297
# >epoch=428, lrate=0.100, error=5.280
# >epoch=429, lrate=0.100, error=5.262
# >epoch=430, lrate=0.100, error=5.245
# >epoch=431, lrate=0.100, error=5.229
# >epoch=432, lrate=0.100, error=5.213
# >epoch=433, lrate=0.100, error=5.197
# >epoch=434, lrate=0.100, error=5.182
# >epoch=435, lrate=0.100, error=5.167
# >epoch=436, lrate=0.100, error=5.152
# >epoch=437, lrate=0.100, error=5.138
# >epoch=438, lrate=0.100, error=5.124
# >epoch=439, lrate=0.100, error=5.110
# >epoch=440, lrate=0.100, error=5.096
# >epoch=441, lrate=0.100, error=5.083
# >epoch=442, lrate=0.100, error=5.070
# >epoch=443, lrate=0.100, error=5.058
# >epoch=444, lrate=0.100, error=5.045
# >epoch=445, lrate=0.100, error=5.033
# >epoch=446, lrate=0.100, error=5.022
# >epoch=447, lrate=0.100, error=5.010
# >epoch=448, lrate=0.100, error=4.999
# >epoch=449, lrate=0.100, error=4.988
# >epoch=450, lrate=0.100, error=4.977
# >epoch=451, lrate=0.100, error=4.966
# >epoch=452, lrate=0.100, error=4.956
# >epoch=453, lrate=0.100, error=4.946
# >epoch=454, lrate=0.100, error=4.936
# >epoch=455, lrate=0.100, error=4.926
# >epoch=456, lrate=0.100, error=4.917
# >epoch=457, lrate=0.100, error=4.907
# >epoch=458, lrate=0.100, error=4.898
# >epoch=459, lrate=0.100, error=4.889
# >epoch=460, lrate=0.100, error=4.880
# >epoch=461, lrate=0.100, error=4.872
# >epoch=462, lrate=0.100, error=4.863
# >epoch=463, lrate=0.100, error=4.855
# >epoch=464, lrate=0.100, error=4.847
# >epoch=465, lrate=0.100, error=4.839
# >epoch=466, lrate=0.100, error=4.831
# >epoch=467, lrate=0.100, error=4.823
# >epoch=468, lrate=0.100, error=4.816
# >epoch=469, lrate=0.100, error=4.808
# >epoch=470, lrate=0.100, error=4.801
# >epoch=471, lrate=0.100, error=4.794
# >epoch=472, lrate=0.100, error=4.787
# >epoch=473, lrate=0.100, error=4.780
# >epoch=474, lrate=0.100, error=4.774
# >epoch=475, lrate=0.100, error=4.767
# >epoch=476, lrate=0.100, error=4.761
# >epoch=477, lrate=0.100, error=4.754
# >epoch=478, lrate=0.100, error=4.748
# >epoch=479, lrate=0.100, error=4.742
# >epoch=480, lrate=0.100, error=4.736
# >epoch=481, lrate=0.100, error=4.730
# >epoch=482, lrate=0.100, error=4.724
# >epoch=483, lrate=0.100, error=4.719
# >epoch=484, lrate=0.100, error=4.713
# >epoch=485, lrate=0.100, error=4.708
# >epoch=486, lrate=0.100, error=4.702
# >epoch=487, lrate=0.100, error=4.697
# >epoch=488, lrate=0.100, error=4.692
# >epoch=489, lrate=0.100, error=4.687
# >epoch=490, lrate=0.100, error=4.682
# >epoch=491, lrate=0.100, error=4.677
# >epoch=492, lrate=0.100, error=4.672
# >epoch=493, lrate=0.100, error=4.667
# >epoch=494, lrate=0.100, error=4.662
# >epoch=495, lrate=0.100, error=4.658
# >epoch=496, lrate=0.100, error=4.653
# >epoch=497, lrate=0.100, error=4.649
# >epoch=498, lrate=0.100, error=4.645
# >epoch=499, lrate=0.100, error=4.640
